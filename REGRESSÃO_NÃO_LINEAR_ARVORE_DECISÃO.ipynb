# %% [markdown]
# <a href="https://colab.research.google.com/github/BiancadeFrancisco/Regressao_NaoLinear_Houses/blob/main/REGRESS%C3%83O_N%C3%83O_LINEAR_ARVORE_DECIS%C3%83O.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# PREVER O PREÇO DE CASAS. FAÇA TODOS OS PASSOS DE TREINAR OS MODELOS EM RANDOM FOREST, ADABOOST E GRADIENT BOOSTING. E TIRE PARA CADA ALGORITMO A FEATURE IMPORTANCE.

# %%
import pandas as pd
import numpy as np

# %%
casa = pd.read_excel("/content/house (1).xlsx")

casa.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea ExterQual  ... WoodDeckSF  OpenPorchSF  \
# 0          2003       196.0        Gd  ...          0           61
# 1          1976         0.0        TA  ...        298            0
# 2          2002       162.0        Gd  ...          0           42
# 3          1970         0.0        TA  ...          0           35
# 4          2000       350.0        Gd  ...        192           84
#
#    EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  \
# ...

# %%
casa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 40 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   LotFrontage    1201 non-null   float64
#  3   LotArea        1460 non-null   int64
#  4   OverallQual    1460 non-null   int64
#  5   OverallCond    1460 non-null   int64
#  6   YearBuilt      1460 non-null   int64
#  7   YearRemodAdd   1460 non-null   int64
#  8   MasVnrArea     1452 non-null   float64
#  9   ExterQual      1460 non-null   object
#  10  ExterCond      1460 non-null   object
#  11  BsmtFinSF1     1460 non-null   int64
#  12  BsmtFinSF2     1460 non-null   int64
#  13  BsmtUnfSF      1460 non-null   int64
#  14  TotalBsmtSF    1460 non-null   int64
#  15  1stFlrSF       1460 non-null   int64
#  16  2ndFlrSF       1460 non-null   int64
#  17  LowQualFinSF   1460 non-null   int64
# ...

# %%
# TRANSFORMAR VARIÁVEL OBJECT:

casa = pd.get_dummies(casa)

casa.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  SalePrice  ExterQual_Ex  \
# 0          2003       196.0         706  ...     208500             0
# 1          1976         0.0         978  ...     181500             0
# 2          2002       162.0         486  ...     223500             0
# 3          1970         0.0         216  ...     140000             0
# 4          2000       350.0         655  ...     250000             0
#
#    ExterQual_Fa  ExterQual_Gd  ExterQual_TA  ExterCond_Ex  ExterCond_Fa  \
# ...

# %%
# TIRAR DADOS NULOS:

casa = casa.dropna()

# %%
# TRANSFORMAR VARIÁVEIS
# chamei nossa variável target de labels
# dizer quem é y e quem é x


labels = np.array(casa['SalePrice']) #y

features = casa.drop("SalePrice", axis = 1) #x

feature_list = list(casa.columns)

casa = np.array(features)

# %%
from sklearn.model_selection import train_test_split

train_features, test_features, train_labels, test_labels = train_test_split(features, labels, test_size = 0.25, random_state=42)

# %%
from sklearn.datasets import make_moons
from sklearn import metrics
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor, GradientBoostingRegressor

# %%
# TREINAR O MODELO RandomForestRegresso

rf = RandomForestRegressor(n_estimators=1000, random_state=42)
rf.fit(train_features, train_labels)
# Out:
# RandomForestRegressor(n_estimators=1000, random_state=42)

# %%
prediction_rf = rf.predict(test_features)

error_rf = abs(prediction_rf - test_labels)

r_sq = rf.score(features, labels)

print("R²:", r_sq)
print("MAE:", metrics.mean_absolute_error(test_labels, prediction_rf))
print("MSE:", metrics.mean_squared_error(test_labels, prediction_rf))
# Out:
# R²: 0.9484004252359669
# MAE: 19150.567960854092
# MSE: 940040806.3832432

# %%
# TREINAR O MODELO AdaBoostRegressor

ada = AdaBoostRegressor(n_estimators=100)
ada.fit(train_features, train_labels)
# Out:
# AdaBoostRegressor(n_estimators=100)

# %%
ada_pred = ada.predict(test_features)

error_ada = abs(ada_pred - test_labels)

r_sq = ada.score(features, labels)

print("R²:", r_sq)
print("MAE:", metrics.mean_absolute_error(test_labels, ada_pred))
print("MSE:", metrics.mean_squared_error(test_labels, ada_pred))
# Out:
# R²: 0.8722251378659325
# MAE: 24331.075202250482
# MSE: 1392609274.2155435

# %%
# TREINAR O MODELO GradientBoostingRegressor

gbr = GradientBoostingRegressor(n_estimators=100)
gbr.fit(train_features, train_labels)
# Out:
# GradientBoostingRegressor()

# %%
gbr_pred = gbr.predict(test_features)

error_gbr = abs(gbr_pred - test_labels)

r_sq = gbr.score(features, labels)

print("R²:", r_sq)
print("MAE:", metrics.mean_absolute_error(test_labels, gbr_pred))
print("MSE:", metrics.mean_squared_error(test_labels, gbr_pred))
# Out:
# R²: 0.9482019599238978
# MAE: 18523.463332734358
# MSE: 869403686.0825741

# %%
# MELHOR MODELO É O GRADIENTE BOOSTING, CFME RESULTADOS.

# %%
# QUAIS VARIÁVEIS SÃO MAIS RELEVANTES DENTRO DA MINHA ARVORE:
# FEATURE_IMPORTANCE: para avaliar quais variáveis são usadas na minha árvore (mais relevantes) e quais não são.
# foi colocar em ordem de relevância, nível de importÂncia. Nesse caso a variávei mais representativa para predizer a minha target, é a temperatura de um dia anterior.

importances = list(rf.feature_importances_)

feature_importance = [(feature, round(importance, 2)) for feature, importance in zip(feature_list, importances)]

feature_importance = sorted(feature_importance, key = lambda x: x[1], reverse=True)

[print("Feature: {:20} Importance {}".format(*pair)) for pair in feature_importance];
# Out:
# Feature: OverallQual          Importance 0.61
# Feature: GrLivArea            Importance 0.09
# Feature: BsmtFinSF1           Importance 0.03
# Feature: TotalBsmtSF          Importance 0.03
# Feature: 2ndFlrSF             Importance 0.03
# Feature: LotArea              Importance 0.02
# Feature: 1stFlrSF             Importance 0.02
# Feature: GarageCars           Importance 0.02
# Feature: LotFrontage          Importance 0.01
# Feature: YearBuilt            Importance 0.01
# Feature: YearRemodAdd         Importance 0.01
# Feature: MasVnrArea           Importance 0.01
# Feature: BsmtUnfSF            Importance 0.01
# Feature: FullBath             Importance 0.01
# Feature: TotRmsAbvGrd         Importance 0.01
# Feature: GarageYrBlt          Importance 0.01
# Feature: GarageArea           Importance 0.01
# Feature: OpenPorchSF          Importance 0.01
# Feature: Id                   Importance 0.0
# Feature: MSSubClass           Importance 0.0
# ...
